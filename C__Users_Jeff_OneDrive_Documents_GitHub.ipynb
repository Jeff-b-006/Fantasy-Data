# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
url = 'https://www.pro-football-reference.com/years/2021/passing.htm'
html = urlopen(url)
stats_page = BeautifulSoup(html)
column_headers = stats_page.find_all('tr')[0]
column_headers = [i.getText() for i in column_headers.find_all('th')]
print(column_headers)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4924/118966213.py in <module>
#       2 html = urlopen(url)
#       3 stats_page = BeautifulSoup(html)
# ----> 4 column_headers = stats_page.find_all('tr')[0]
#       5 column_headers = [i.getText() for i in column_headers.find_all('th')]
#       6 print(column_headers)
#
# IndexError: list index out of range

# %%
rows = stats_page.find_all('tr')[1:]
player_stats = []
for i in range(len(rows)):
    player_stats.append([col.getText()for col in rows[i].find_all('td')])
print(player_stats[1])
# Out:
# ['Christian McCaffrey*+', 'CAR', '23', 'RB', '16', '16', '142', '116', '81.7%', '1005', '8.7', '4', '58', '28', '7.1', '7.3', '62.8', '1']

# %%
data = pd.DataFrame(qb_stats, columns = column_headers[1:])
data.head()
# Out:
#                   Player   Tm Age Pos   G  GS  Tgt  Rec  Ctch%   Yds   Y/R TD  \
# 0       Michael Thomas*+  NOR  26  WR  16  15  185  149  80.5%  1725  11.6  9
# 1  Christian McCaffrey*+  CAR  23  RB  16  16  142  116  81.7%  1005   8.7  4
# 2          Keenan Allen*  LAC  27  WR  16  16  149  104  69.8%  1199  11.5  6
# 3      DeAndre Hopkins*+  HOU  27  WR  15  15  150  104  69.3%  1165  11.2  7
# 4         Julian Edelman  NWE  33  WR  16  13  153  100  65.4%  1117  11.2  6
#
#    1D Lng Y/Tgt  R/G    Y/G Fmb
# 0  91  49   9.3  9.3  107.8   1
# 1  58  28   7.1  7.3   62.8   1
# 2  63  45   8.0  6.5   74.9   0
# 3  68  43   7.8  6.9   77.7   0
# 4  54  44   7.3  6.3   69.8   3

# %%
data.to_csv(r'C:\Users\Jeff\OneDrive\Documents\Fantasy Data\19rec.csv', index = False)
